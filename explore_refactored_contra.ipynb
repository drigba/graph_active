# %%
import random
import wandb
import torch
import torch.nn.functional as F
import torch_geometric.transforms as T 
from torch_geometric.seed import seed_everything
from query_strategies import *
from augmentation import *
from model import *
from model_wrapper import *
from trainers import *
from util import *

from hivegraph.contrastive.grace import GRACE

from GRACE_new import GRACENew

# %%
wandb.login()
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: banfizsombor1999. Use `wandb login --relogin` to force relogin
# True

# %%
random.seed(0)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# dataset = Planetoid(root='/tmp/Cora', name='Cora')
# generate_balanced_data_splits(dataset,10,"data_splits\\cora_splits")

# %%
DROPOUT= 0.3
NUM_PASSES = 100
BUDGET = 150
EPOCHS = 100
SIGNIFICANCE_ITERATIONS = 10

NOISE_PROB = 0.4
NOISE_LEVEL = 0.5
LATENT_NOISE_LEVEL = 0.25

# %%
# Augmentations
drop_edge = DropEdge(DROPOUT)
noise_feature_all = NoiseFeature(NOISE_LEVEL, 1)
noise_feature_col = NoiseFeature(NOISE_LEVEL, NOISE_PROB, "col")
noise_feature_row = NoiseFeature(NOISE_LEVEL, NOISE_PROB, "row")
noise_latent = NoiseLatent(LATENT_NOISE_LEVEL)

mask_feature_col = MaskFeature(DROPOUT, "col")

costa = COSTA()

drop_edge_noise_all = T.Compose([drop_edge, noise_feature_all])
drop_edge_noise_col = T.Compose([drop_edge, noise_feature_col])
drop_edge_noise_row = T.Compose([drop_edge, noise_feature_row])
drop_edge_mask_col = T.Compose([drop_edge, mask_feature_col])

# %%
# Weighted augmentations
edge_weights = torch.load("data/drop_weights.pt").to(device)
feature_weights = torch.load("data/feature_weights.pt").to(device)

drop_edge_weighted = DropEdgeWeighted(edge_weights, DROPOUT, threshold=0.7)
drop_feature_weighted = MaskFeatureWeighted(feature_weights, 0.2)
noise_feature_weighted = NoiseFeatureWeighted(feature_weights, NOISE_LEVEL, th=0.7)

weighted_augmentation = T.Compose([drop_edge_weighted, noise_feature_weighted])
# Out:
# /tmp/ipykernel_73237/2021967292.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   edge_weights = torch.load("data/drop_weights.pt").to(device)
# /tmp/ipykernel_73237/2021967292.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   feature_weights = torch.load("data/feature_weights.pt").to(device)

# %%
# Strategies

random_query = RandomQuery()
entropy_query = EntropyQuery()

augment_sum_entropy = AugmentGraphSumEntropyQuery(drop_edge_noise_all, NUM_PASSES,0.0)
augment_logit_change = AugmentGraphLogitChange(drop_edge_noise_all, NUM_PASSES,0.1)
augment_latent = AugmentGraphSumQueryLatent(noise_latent, NUM_PASSES)

augment_sum_entropy_with_original = AugmentGraphSumEntropyQuery(drop_edge_noise_all, NUM_PASSES, 1.0)

augment_sum_entropy_ratio = AugmentGraphRatioEntropyQuery(drop_edge_noise_all, NUM_PASSES)


augment_sum_entropy_with_original_mask = AugmentGraphSumEntropyQuery(drop_edge_mask_col, NUM_PASSES, 1.0)

contrastive_minmax =  ContrastiveMinMax()

augment_latent_logit_change = AugmentGraphLogitChangeLatent(costa, NUM_PASSES)

augment_expected_graph = AugmentGraphExpectedGraph(drop_edge_noise_all, NUM_PASSES)
augment_sum_entropy_neighbor =AugmentGraphSumEntropyQueryNeighborhood(drop_edge_noise_all, NUM_PASSES, 1,1.0)

acc_change = DropNodeAccChange()

# %%
weighted_augment_sum_entropy_with_original = AugmentGraphSumEntropyQuery(weighted_augmentation, NUM_PASSES, 1.0)
weighted_augment_logit_change = AugmentGraphLogitChange(weighted_augmentation, NUM_PASSES,0.1)

# %%
data_splits = [torch.load(f"data_splits/split_{i}.pt") for i in range(10)]
# Out:
# /tmp/ipykernel_73237/1640822956.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data_splits = [torch.load(f"data_splits/split_{i}.pt") for i in range(10)]

# %%
type(data_splits[0])
# Out:
# torch_geometric.data.data.Data

# %%
dataset = data_splits[0].to(device)
model = GRACENew(num_features=dataset.num_features,hidden=128, num_layers=2,
                 drop_edge_rate_1=0.3,drop_edge_rate_2=0.3,
                 drop_feature_rate_1=0.3,drop_feature_rate_2=0.3,
                 ratio=0.5).to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=0.001, weight_decay=5e-4)
wrapped_model = GRACEModelWrapper(model,optimizer)
trainer = Trainer()

# %%
# trainer.train(wrapped_model, dataset, 200)
# print("Training done")
# wrapped_model.train_step(dataset)

# %%
wandb.finish()

# %%
STRATEGIES = [  augment_sum_entropy_with_original]
# STRATEGIES = noises_latent
final_accs = torch.zeros((len(STRATEGIES), BUDGET, SIGNIFICANCE_ITERATIONS))
final_auc = torch.zeros((len(STRATEGIES), BUDGET, SIGNIFICANCE_ITERATIONS))


for strategy_ix, strategy in enumerate(STRATEGIES):
    print(f"Strategy: {strategy}")
    init_wandb(strategy, f"SEED_SET", "CORA")
    data_splits = [torch.load(f"data_splits/split_{i}.pt") for i in range(10)]
    

    wrapped_models = []
    for si in range(SIGNIFICANCE_ITERATIONS):
        
        lambda_ = 1.0
        seed_everything(si)
        model = GRACENew(num_features=data_splits[0].num_features,hidden=128, num_layers=2, drop_edge_rate_1=0.3,drop_edge_rate_2=0.3,drop_feature_rate_1=0.3,drop_feature_rate_2=0.3, lambda_=lambda_).to(device)
        optimizer = torch.optim.Adam(model.parameters(), lr=0.001, weight_decay=5e-4)
        wrapped_model = GRACENEWModelWrapper(model,optimizer)
        
        dataset = data_splits[si].to(device)
        trainer = Trainer()
        trainer.train(wrapped_model, dataset, 200)
        
        wrapped_models.append(wrapped_model)
        print(f"Model {si} trained")
        
    for b in range(1,BUDGET+1):

        budget_accuracies = []
        budget_aucs = []
        for si in range(SIGNIFICANCE_ITERATIONS):
            seed_everything(si)
            dataset = data_splits[si].to(device)
            num_features = dataset.num_features
            num_classes = dataset.y.max().item() + 1
            
            wrapped_model = wrapped_models[si]
            
            print(f"{b} - {si} - {strategy}")
            
            
            # ALWAYS CALL TEST BEFORE STRATEGY
            acc = trainer.test(wrapped_model, dataset)
            chosen_node = strategy(wrapped_model, dataset, dataset.train_pool)
            dataset.train_pool[chosen_node] = False
            dataset.train_mask[chosen_node] = True
            budget_accuracies.append(acc)
            
            wrapped_model.reset_predictor()


        budget_accuracies = torch.tensor(budget_accuracies)
        budget_aucs = torch.tensor(budget_aucs)
        final_accs[strategy_ix, b-1, :] = budget_accuracies
        # final_auc[strategy_ix, b-1, :] = budget_aucs
        m = budget_accuracies.mean()
        std = budget_accuracies.std()
        wandb.log({"accuracy_mean": m.item(), "step":b})
        wandb.log({"accuracy_std": std.item(), "step": b})
wandb.finish()
# Out:
# Strategy: AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# Tracking run with wandb version 0.18.6
# Run data is saved locally in <code>/home/banfizsombor/work/graph_active/wandb/run-20241122_122840-g4vyjrvt</code>
# Syncing run <strong><a href='https://wandb.ai/banfizsombor1999/graph-active-learning/runs/g4vyjrvt' target="_blank">AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)_SEED_SET</a></strong> to <a href='https://wandb.ai/banfizsombor1999/graph-active-learning' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/banfizsombor1999/graph-active-learning' target="_blank">https://wandb.ai/banfizsombor1999/graph-active-learning</a>
#  View run at <a href='https://wandb.ai/banfizsombor1999/graph-active-learning/runs/g4vyjrvt' target="_blank">https://wandb.ai/banfizsombor1999/graph-active-learning/runs/g4vyjrvt</a>
# /tmp/ipykernel_105054/160421949.py:10: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data_splits = [torch.load(f"data_splits/split_{i}.pt") for i in range(10)]
# Model 0 trained
# Model 1 trained
# Model 2 trained
# Model 3 trained
# Model 4 trained
# Model 5 trained
# Model 6 trained
# Model 7 trained
# Model 8 trained
# Model 9 trained
# 1 - 0 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 1 - 1 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 1 - 2 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 1 - 3 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 1 - 4 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 1 - 5 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 1 - 6 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 1 - 7 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 1 - 8 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 1 - 9 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 2 - 0 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 2 - 1 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 2 - 2 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 2 - 3 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 2 - 4 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 2 - 5 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 2 - 6 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 2 - 7 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 2 - 8 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 2 - 9 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 3 - 0 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 3 - 1 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 3 - 2 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 3 - 3 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 3 - 4 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 3 - 5 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 3 - 6 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 3 - 7 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 3 - 8 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 3 - 9 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 4 - 0 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 4 - 1 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 4 - 2 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 4 - 3 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 4 - 4 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 4 - 5 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 4 - 6 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 4 - 7 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 4 - 8 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 4 - 9 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 5 - 0 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 5 - 1 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 5 - 2 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 5 - 3 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 5 - 4 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 5 - 5 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 5 - 6 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 5 - 7 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 5 - 8 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 5 - 9 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 6 - 0 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 6 - 1 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 6 - 2 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 6 - 3 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 6 - 4 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 6 - 5 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 6 - 6 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 6 - 7 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 6 - 8 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 6 - 9 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 7 - 0 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 7 - 1 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 7 - 2 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 7 - 3 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 7 - 4 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 7 - 5 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 7 - 6 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 7 - 7 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 7 - 8 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 7 - 9 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 8 - 0 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 8 - 1 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 8 - 2 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 8 - 3 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 8 - 4 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 8 - 5 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 8 - 6 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 8 - 7 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 8 - 8 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 8 - 9 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 9 - 0 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 9 - 1 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 9 - 2 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 9 - 3 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 9 - 4 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 9 - 5 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 9 - 6 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 9 - 7 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 9 - 8 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 9 - 9 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 10 - 0 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 10 - 1 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 10 - 2 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 10 - 3 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 10 - 4 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 10 - 5 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 10 - 6 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 10 - 7 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 10 - 8 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 10 - 9 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 11 - 0 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 11 - 1 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 11 - 2 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 11 - 3 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 11 - 4 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 11 - 5 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 11 - 6 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 11 - 7 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 11 - 8 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 11 - 9 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 12 - 0 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 12 - 1 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 12 - 2 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 12 - 3 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 12 - 4 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 12 - 5 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 12 - 6 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 12 - 7 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 12 - 8 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 12 - 9 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 13 - 0 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 13 - 1 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 13 - 2 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 13 - 3 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 13 - 4 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 13 - 5 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 13 - 6 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 13 - 7 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 13 - 8 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 13 - 9 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 14 - 0 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 14 - 1 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 14 - 2 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 14 - 3 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 14 - 4 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 14 - 5 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 14 - 6 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 14 - 7 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 14 - 8 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 14 - 9 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 15 - 0 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 15 - 1 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 15 - 2 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 15 - 3 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 15 - 4 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 15 - 5 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 15 - 6 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 15 - 7 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 15 - 8 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 15 - 9 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 16 - 0 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 16 - 1 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 16 - 2 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 16 - 3 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 16 - 4 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 16 - 5 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 16 - 6 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 16 - 7 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 16 - 8 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 16 - 9 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 17 - 0 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 17 - 1 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 17 - 2 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 17 - 3 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 17 - 4 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 17 - 5 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 17 - 6 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 17 - 7 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 17 - 8 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 17 - 9 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 18 - 0 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 18 - 1 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 18 - 2 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 18 - 3 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 18 - 4 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 18 - 5 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 18 - 6 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 18 - 7 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 18 - 8 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 18 - 9 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 19 - 0 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 19 - 1 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 19 - 2 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 19 - 3 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 19 - 4 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
#
- 1 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 55 - 2 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 55 - 3 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 55 - 4 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 55 - 5 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 55 - 6 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 55 - 7 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 55 - 8 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 55 - 9 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 56 - 0 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 56 - 1 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 56 - 2 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 56 - 3 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 56 - 4 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 56 - 5 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 56 - 6 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 56 - 7 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 56 - 8 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 56 - 9 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 57 - 0 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 57 - 1 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 57 - 2 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 57 - 3 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 57 - 4 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 57 - 5 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 57 - 6 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 57 - 7 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 57 - 8 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 57 - 9 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 58 - 0 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 58 - 1 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 58 - 2 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 58 - 3 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# ...
# 133 - 2 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 133 - 3 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 133 - 4 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 133 - 5 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 133 - 6 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 133 - 7 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 133 - 8 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 133 - 9 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 134 - 0 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 134 - 1 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 134 - 2 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 134 - 3 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 134 - 4 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 134 - 5 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 134 - 6 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 134 - 7 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 134 - 8 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 134 - 9 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 135 - 0 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 135 - 1 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 135 - 2 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 135 - 3 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 135 - 4 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 135 - 5 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 135 - 6 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 135 - 7 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 135 - 8 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 135 - 9 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 136 - 0 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 136 - 1 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 136 - 2 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 136 - 3 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 136 - 4 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 136 - 5 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 136 - 6 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 136 - 7 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 136 - 8 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 136 - 9 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 137 - 0 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 137 - 1 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 137 - 2 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 137 - 3 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 137 - 4 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 137 - 5 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 137 - 6 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 137 - 7 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 137 - 8 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 137 - 9 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 138 - 0 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 138 - 1 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 138 - 2 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 138 - 3 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 138 - 4 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 138 - 5 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 138 - 6 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 138 - 7 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 138 - 8 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 138 - 9 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 139 - 0 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 139 - 1 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 139 - 2 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 139 - 3 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 139 - 4 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 139 - 5 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 139 - 6 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 139 - 7 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 139 - 8 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 139 - 9 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 140 - 0 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 140 - 1 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 140 - 2 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 140 - 3 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 140 - 4 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 140 - 5 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 140 - 6 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 140 - 7 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 140 - 8 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 140 - 9 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 141 - 0 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 141 - 1 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 141 - 2 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 141 - 3 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 141 - 4 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 141 - 5 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 141 - 6 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 141 - 7 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 141 - 8 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 141 - 9 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 142 - 0 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 142 - 1 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 142 - 2 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 142 - 3 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 142 - 4 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 142 - 5 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 142 - 6 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 142 - 7 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 142 - 8 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 142 - 9 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 143 - 0 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 143 - 1 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 143 - 2 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 143 - 3 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 143 - 4 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 143 - 5 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 143 - 6 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 143 - 7 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 143 - 8 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 143 - 9 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 144 - 0 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 144 - 1 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 144 - 2 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 144 - 3 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 144 - 4 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 144 - 5 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 144 - 6 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 144 - 7 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 144 - 8 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 144 - 9 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 145 - 0 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 145 - 1 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 145 - 2 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 145 - 3 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 145 - 4 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 145 - 5 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 145 - 6 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 145 - 7 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 145 - 8 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 145 - 9 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 146 - 0 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 146 - 1 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 146 - 2 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 146 - 3 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 146 - 4 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 146 - 5 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 146 - 6 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 146 - 7 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 146 - 8 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 146 - 9 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 147 - 0 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 147 - 1 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 147 - 2 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 147 - 3 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 147 - 4 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 147 - 5 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 147 - 6 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 147 - 7 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 147 - 8 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 147 - 9 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 148 - 0 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 148 - 1 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 148 - 2 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 148 - 3 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 148 - 4 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 148 - 5 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 148 - 6 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 148 - 7 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 148 - 8 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 148 - 9 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 149 - 0 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 149 - 1 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 149 - 2 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 149 - 3 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 149 - 4 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 149 - 5 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 149 - 6 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 149 - 7 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 149 - 8 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 149 - 9 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 150 - 0 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 150 - 1 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 150 - 2 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 150 - 3 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 150 - 4 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 150 - 5 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 150 - 6 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 150 - 7 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 150 - 8 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
# 150 - 9 - AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)
#     <style>
#         .wandb-row {
#             display: flex;
#             flex-direction: row;
#             flex-wrap: wrap;
#             justify-content: flex-start;
#             width: 100%;
#         }
#         .wandb-col {
#             display: flex;
#             flex-direction: column;
#             flex-basis: 100%;
#             flex: 1;
#             padding: 10px;
#         }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy_mean</td><td>▂▁▄▄▄▅▆▆▆▇▇▇▇▇▇█████████████████████████</td></tr><tr><td>accuracy_std</td><td>█████▆▇▇█▆▂▂▂▁▂▁▂▂▂▂▂▂▁▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>step</td><td>▁▁▁▂▂▂▂▂▂▂▂▃▃▃▃▃▃▃▄▄▄▄▅▅▅▅▅▆▆▆▇▇▇▇▇▇▇▇██</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy_mean</td><td>0.8172</td></tr><tr><td>accuracy_std</td><td>0.00985</td></tr><tr><td>step</td><td>150</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">AugmentGraphLogitChange([DropEdge, NoiseFeature], original_weight=0.1)_SEED_SET</strong> at: <a href='https://wandb.ai/banfizsombor1999/graph-active-learning/runs/g4vyjrvt' target="_blank">https://wandb.ai/banfizsombor1999/graph-active-learning/runs/g4vyjrvt</a><br/> View project at: <a href='https://wandb.ai/banfizsombor1999/graph-active-learning' target="_blank">https://wandb.ai/banfizsombor1999/graph-active-learning</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20241122_122840-g4vyjrvt/logs</code>

# %%
wandb.finish()

# %%
train_mask = dataset.train_mask.detach().cpu().numpy()

# %%
np.tile(train_mask,11).shape
# Out:
# (29788,)

# %%
ol = []
for _ in range(11):
    ol.append(wrapped_model(dataset))
ol = torch.cat(ol)

# %%
ol.shape
# Out:
# torch.Size([29788, 128])
