# %%
import random
import wandb
import torch
import torch.nn.functional as F
import torch_geometric.transforms as T 
from torch_geometric.seed import seed_everything
from query_strategies import *
from augmentation import *
from model import *
from model_wrapper import *
from trainers import *
from util import *

from hivegraph.contrastive.grace import GRACE

from GRACE_new import GRACENew

from GRACE_new2 import GRACENew2, GRACEEncoder
from copy import deepcopy

# %%
wandb.login()
# Out:
# True

# %%
random.seed(0)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# dataset = Planetoid(root='/tmp/Cora', name='Cora')
# generate_balanced_data_splits(dataset,10,"data_splits\\cora_splits")

# %%
DROPOUT= 0.3
NUM_PASSES = 100
BUDGET = 150
EPOCHS = 100
SIGNIFICANCE_ITERATIONS = 10

NOISE_PROB = 0.4
NOISE_LEVEL = 0.5
LATENT_NOISE_LEVEL = 0.25

# %%
# Augmentations
drop_edge = DropEdge(DROPOUT)
noise_feature_all = NoiseFeature(NOISE_LEVEL, 1)
noise_feature_col = NoiseFeature(NOISE_LEVEL, NOISE_PROB, "col")
noise_feature_row = NoiseFeature(NOISE_LEVEL, NOISE_PROB, "row")
noise_latent = NoiseLatent(LATENT_NOISE_LEVEL)

mask_feature_col = MaskFeature(DROPOUT, "col")

costa = COSTA()

drop_edge_noise_all = T.Compose([drop_edge, noise_feature_all])
drop_edge_noise_col = T.Compose([drop_edge, noise_feature_col])
drop_edge_noise_row = T.Compose([drop_edge, noise_feature_row])
drop_edge_mask_col = T.Compose([drop_edge, mask_feature_col])

# %%
# Weighted augmentations
edge_weights = torch.load("data/drop_weights.pt").to(device)
feature_weights = torch.load("data/feature_weights.pt").to(device)

drop_edge_weighted = DropEdgeWeighted(edge_weights, DROPOUT, threshold=0.7)
drop_feature_weighted = MaskFeatureWeighted(feature_weights, 0.2)
noise_feature_weighted = NoiseFeatureWeighted(feature_weights, NOISE_LEVEL, th=0.7)

weighted_augmentation = T.Compose([drop_edge_weighted, noise_feature_weighted])
# Out:
# /tmp/ipykernel_81385/2021967292.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   edge_weights = torch.load("data/drop_weights.pt").to(device)
# /tmp/ipykernel_81385/2021967292.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   feature_weights = torch.load("data/feature_weights.pt").to(device)

# %%
# Strategies
random_query = RandomQuery()
entropy_query = EntropyQuery()

augment_sum_entropy = AugmentGraphSumEntropyQuery(drop_edge_noise_all, NUM_PASSES,0.0)
augment_logit_change = AugmentGraphLogitChange(drop_edge_noise_all, NUM_PASSES,0.1)
augment_latent = AugmentGraphSumQueryLatent(noise_latent, NUM_PASSES)

augment_sum_entropy_with_original = AugmentGraphSumEntropyQuery(drop_edge_noise_all, NUM_PASSES, 1.0)
# augment_sum_entropy_with_original = AugmentGraphSumEntropyQuery(drop_edge_mask_col, NUM_PASSES, 1.0)

augment_sum_entropy_ratio = AugmentGraphRatioEntropyQuery(drop_edge_noise_all, NUM_PASSES)


augment_sum_entropy_with_original_mask = AugmentGraphSumEntropyQuery(drop_edge_mask_col, NUM_PASSES, 1.0)

contrastive_minmax =  ContrastiveMinMax()

augment_latent_logit_change = AugmentGraphLogitChangeLatent(costa, NUM_PASSES)

augment_expected_graph = AugmentGraphExpectedGraph(drop_edge_noise_all, NUM_PASSES)
augment_sum_entropy_neighbor =AugmentGraphSumEntropyQueryNeighborhood(drop_edge_noise_all, NUM_PASSES, 1,1.0)

acc_change = DropNodeAccChange()

# %%
weighted_augment_sum_entropy_with_original = AugmentGraphSumEntropyQuery(weighted_augmentation, NUM_PASSES, 1.0)
weighted_augment_logit_change = AugmentGraphLogitChange(weighted_augmentation, NUM_PASSES,0.1)

# %%
data_splits = [torch.load(f"data_splits/split_{i}.pt") for i in range(10)]
# Out:
# /tmp/ipykernel_81385/1640822956.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data_splits = [torch.load(f"data_splits/split_{i}.pt") for i in range(10)]

# %%
def reset_models(original_models, trained_model):
    for original_model, trained_model in zip(original_models, trained_model):
        trained_model.load_state_dict(original_model.state_dict())
        trained_model.optimizer.load_state_dict(original_model.optimizer.state_dict())

# %%
RETRAIN_MODELS = False

# %%
wandb.finish()

# %%
STRATEGIES = [  augment_sum_entropy_with_original]
# STRATEGIES = noises_latent
final_accs = torch.zeros((len(STRATEGIES), BUDGET, SIGNIFICANCE_ITERATIONS))
final_auc = torch.zeros((len(STRATEGIES), BUDGET, SIGNIFICANCE_ITERATIONS))


for strategy_ix, strategy in enumerate(STRATEGIES):
    print(f"Strategy: {strategy}")
    init_wandb(strategy, f"NOISE_COL_TRAIN", "CORA")
    data_splits = [torch.load(f"data_splits/split_{i}.pt") for i in range(10)]
    

    wrapped_models = []
    original_wrapped_models = []
    # Pretraining
    for si in range(SIGNIFICANCE_ITERATIONS):
        dataset = data_splits[si].to(device)
        seed_everything(si)
        hidden = 128
        projection_dim = 128
        num_layers = 2
        
        
        encoder_module = GRACEEncoder(
            in_channels=dataset.num_features,
            out_channels=hidden
        )
        
        projection_head = torch.nn.Sequential(
            torch.nn.Linear(hidden, projection_dim),
            torch.nn.ELU(),
            torch.nn.Linear(projection_dim, projection_dim),
        )

        model = GRACENew2(encoder_module=encoder_module,
                          projection_head=projection_head,
                          augmentor1=train_augmentor,
                          augmentor2=train_augmentor).to(device)
        
        train_augmentor = drop_edge_noise_col
        optimizer = torch.optim.Adam(model.parameters(), lr=0.001, weight_decay=5e-4)
        wrapped_model = GRACE2ModelWrapper(model,optimizer)
        original_wrapped_models.append(deepcopy(wrapped_model))

        trainer = Trainer()
        trainer.train(wrapped_model, dataset, 200)
        wrapped_models.append(wrapped_model)
        print(f"Model {si} trained")
        
    for b in range(1,BUDGET+1):

        budget_accuracies = []
        budget_aucs = []
        for si in range(SIGNIFICANCE_ITERATIONS):
            seed_everything(si)
            dataset = data_splits[si].to(device)            
            wrapped_model = wrapped_models[si]
            print(f"{b} - {si} - {strategy}")
            
            
            # ALWAYS CALL TEST BEFORE STRATEGY
            acc = trainer.test(wrapped_model, dataset)
            chosen_node = strategy(wrapped_model, dataset, dataset.train_pool)
            dataset.train_pool[chosen_node] = False
            dataset.train_mask[chosen_node] = True
            budget_accuracies.append(acc)
            
            if RETRAIN_MODELS:
                print(f"Model {si} retraining...")
                reset_models(original_wrapped_models, wrapped_models)
                trainer.train(wrapped_model, dataset, 200)
            
            wrapped_model.reset_predictor()


        budget_accuracies = torch.tensor(budget_accuracies)
        budget_aucs = torch.tensor(budget_aucs)
        final_accs[strategy_ix, b-1, :] = budget_accuracies
        # final_auc[strategy_ix, b-1, :] = budget_aucs
        m = budget_accuracies.mean()
        std = budget_accuracies.std()
        wandb.log({"accuracy_mean": m.item(), "step":b})
        wandb.log({"accuracy_std": std.item(), "step": b})
wandb.finish()
# Out:
# Strategy: AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# Tracking run with wandb version 0.18.6
# Run data is saved locally in <code>/home/banfizsombor/work/graph_active/wandb/run-20241205_151434-5nf3f8eo</code>
# Syncing run <strong><a href='https://wandb.ai/banfizsombor1999/graph-active-learning/runs/5nf3f8eo' target="_blank">AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)_NOISE_COL_TRAIN</a></strong> to <a href='https://wandb.ai/banfizsombor1999/graph-active-learning' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/banfizsombor1999/graph-active-learning' target="_blank">https://wandb.ai/banfizsombor1999/graph-active-learning</a>
#  View run at <a href='https://wandb.ai/banfizsombor1999/graph-active-learning/runs/5nf3f8eo' target="_blank">https://wandb.ai/banfizsombor1999/graph-active-learning/runs/5nf3f8eo</a>
# /tmp/ipykernel_81385/2792336969.py:10: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data_splits = [torch.load(f"data_splits/split_{i}.pt") for i in range(10)]
# Model 0 trained
# Model 1 trained
# Model 2 trained
# Model 3 trained
# Model 4 trained
# Model 5 trained
# Model 6 trained
# Model 7 trained
# Model 8 trained
# Model 9 trained
# 1 - 0 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 1 - 1 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 1 - 2 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 1 - 3 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 1 - 4 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 1 - 5 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 1 - 6 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 1 - 7 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 1 - 8 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 1 - 9 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 2 - 0 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 2 - 1 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 2 - 2 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 2 - 3 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 2 - 4 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 2 - 5 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 2 - 6 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 2 - 7 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 2 - 8 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 2 - 9 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 3 - 0 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 3 - 1 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 3 - 2 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 3 - 3 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 3 - 4 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 3 - 5 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 3 - 6 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 3 - 7 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 3 - 8 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 3 - 9 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 4 - 0 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 4 - 1 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 4 - 2 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 4 - 3 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 4 - 4 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 4 - 5 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 4 - 6 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 4 - 7 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 4 - 8 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 4 - 9 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 5 - 0 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 5 - 1 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 5 - 2 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 5 - 3 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 5 - 4 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 5 - 5 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 5 - 6 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 5 - 7 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 5 - 8 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 5 - 9 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 6 - 0 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 6 - 1 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 6 - 2 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 6 - 3 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 6 - 4 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 6 - 5 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 6 - 6 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 6 - 7 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 6 - 8 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 6 - 9 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 7 - 0 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 7 - 1 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 7 - 2 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 7 - 3 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 7 - 4 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 7 - 5 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 7 - 6 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 7 - 7 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 7 - 8 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 7 - 9 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 8 - 0 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 8 - 1 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 8 - 2 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 8 - 3 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 8 - 4 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 8 - 5 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 8 - 6 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 8 - 7 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 8 - 8 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 8 - 9 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 9 - 0 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 9 - 1 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 9 - 2 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 9 - 3 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 9 - 4 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 9 - 5 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 9 - 6 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 9 - 7 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 9 - 8 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 9 - 9 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 10 - 0 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 10 - 1 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 10 - 2 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 10 - 3 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 10 - 4 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 10 - 5 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 10 - 6 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 10 - 7 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 10 - 8 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 10 - 9 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 11 - 0 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 11 - 1 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 11 - 2 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 11 - 3 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 11 - 4 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 11 - 5 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 11 - 6 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 11 - 7 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 11 - 8 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 11 - 9 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 12 - 0 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 12 - 1 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 12 - 2 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 12 - 3 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 12 - 4 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 12 - 5 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 12 - 6 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 12 - 7 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 12 - 8 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 12 - 9 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 13 - 0 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 13 - 1 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 13 - 2 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 13 - 3 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 13 - 4 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 13 - 5 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 13 - 6 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 13 - 7 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 13 - 8 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 13 - 9 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 14 - 0 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 14 - 1 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 14 - 2 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 14 - 3 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 14 - 4 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 14 - 5 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 14 - 6 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 14 - 7 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 14 - 8 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
#
- 4 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 50 - 5 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 50 - 6 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 50 - 7 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 50 - 8 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 50 - 9 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 51 - 0 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 51 - 1 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 51 - 2 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 51 - 3 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 51 - 4 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 51 - 5 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 51 - 6 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 51 - 7 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 51 - 8 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 51 - 9 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 52 - 0 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 52 - 1 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 52 - 2 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 52 - 3 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 52 - 4 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 52 - 5 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 52 - 6 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 52 - 7 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 52 - 8 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 52 - 9 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 53 - 0 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 53 - 1 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 53 - 2 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 53 - 3 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 53 - 4 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 53 - 5 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 53 - 6 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 53 - 7 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 53 - 8 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 53 - 9 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 54 - 0 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 54 - 1 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 54 - 2 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 54 - 3 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 54 - 4 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 54 - 5 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 54 - 6 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 54 - 7 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 54 - 8 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 54 - 9 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 55 - 0 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 55 - 1 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 55 - 2 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 55 - 3 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 55 - 4 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 55 - 5 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 55 - 6 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 55 - 7 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 55 - 8 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 55 - 9 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 56 - 0 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 56 - 1 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 56 - 2 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# ...
# 133 - 9 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 134 - 0 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 134 - 1 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 134 - 2 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 134 - 3 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 134 - 4 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 134 - 5 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 134 - 6 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 134 - 7 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 134 - 8 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 134 - 9 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 135 - 0 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 135 - 1 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 135 - 2 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 135 - 3 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 135 - 4 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 135 - 5 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 135 - 6 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 135 - 7 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 135 - 8 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 135 - 9 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 136 - 0 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 136 - 1 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 136 - 2 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 136 - 3 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 136 - 4 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 136 - 5 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 136 - 6 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 136 - 7 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 136 - 8 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 136 - 9 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 137 - 0 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 137 - 1 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 137 - 2 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 137 - 3 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 137 - 4 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 137 - 5 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 137 - 6 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 137 - 7 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 137 - 8 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 137 - 9 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 138 - 0 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 138 - 1 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 138 - 2 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 138 - 3 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 138 - 4 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 138 - 5 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 138 - 6 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 138 - 7 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 138 - 8 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 138 - 9 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 139 - 0 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 139 - 1 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 139 - 2 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 139 - 3 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 139 - 4 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 139 - 5 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 139 - 6 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 139 - 7 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 139 - 8 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 139 - 9 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 140 - 0 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 140 - 1 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 140 - 2 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 140 - 3 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 140 - 4 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 140 - 5 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 140 - 6 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 140 - 7 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 140 - 8 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 140 - 9 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 141 - 0 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 141 - 1 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 141 - 2 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 141 - 3 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 141 - 4 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 141 - 5 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 141 - 6 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 141 - 7 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 141 - 8 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 141 - 9 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 142 - 0 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 142 - 1 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 142 - 2 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 142 - 3 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 142 - 4 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 142 - 5 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 142 - 6 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 142 - 7 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 142 - 8 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 142 - 9 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 143 - 0 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 143 - 1 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 143 - 2 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 143 - 3 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 143 - 4 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 143 - 5 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 143 - 6 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 143 - 7 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 143 - 8 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 143 - 9 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 144 - 0 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 144 - 1 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 144 - 2 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 144 - 3 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 144 - 4 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 144 - 5 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 144 - 6 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 144 - 7 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 144 - 8 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 144 - 9 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 145 - 0 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 145 - 1 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 145 - 2 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 145 - 3 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 145 - 4 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 145 - 5 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 145 - 6 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 145 - 7 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 145 - 8 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 145 - 9 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 146 - 0 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 146 - 1 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 146 - 2 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 146 - 3 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 146 - 4 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 146 - 5 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 146 - 6 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 146 - 7 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 146 - 8 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 146 - 9 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 147 - 0 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 147 - 1 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 147 - 2 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 147 - 3 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 147 - 4 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 147 - 5 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 147 - 6 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 147 - 7 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 147 - 8 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 147 - 9 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 148 - 0 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 148 - 1 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 148 - 2 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 148 - 3 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 148 - 4 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 148 - 5 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 148 - 6 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 148 - 7 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 148 - 8 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 148 - 9 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 149 - 0 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 149 - 1 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 149 - 2 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 149 - 3 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 149 - 4 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 149 - 5 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 149 - 6 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 149 - 7 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 149 - 8 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 149 - 9 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 150 - 0 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 150 - 1 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 150 - 2 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 150 - 3 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 150 - 4 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 150 - 5 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 150 - 6 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 150 - 7 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 150 - 8 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
# 150 - 9 - AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)
#     <style>
#         .wandb-row {
#             display: flex;
#             flex-direction: row;
#             flex-wrap: wrap;
#             justify-content: flex-start;
#             width: 100%;
#         }
#         .wandb-col {
#             display: flex;
#             flex-direction: column;
#             flex-basis: 100%;
#             flex: 1;
#             padding: 10px;
#         }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy_mean</td><td>▁▂▄▅▅▅▅▅▅▅▅▆▆▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇██████</td></tr><tr><td>accuracy_std</td><td>█▄▄▃▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>step</td><td>▁▁▁▂▂▂▂▂▃▃▃▃▃▃▃▄▄▄▄▄▄▅▅▆▆▆▆▆▆▆▇▇▇▇▇▇████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy_mean</td><td>0.8102</td></tr><tr><td>accuracy_std</td><td>0.00827</td></tr><tr><td>step</td><td>150</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">AugmentGraphSumEntropyQuery([DropEdge, MaskFeature], original_weight=1.0)_NOISE_COL_TRAIN</strong> at: <a href='https://wandb.ai/banfizsombor1999/graph-active-learning/runs/5nf3f8eo' target="_blank">https://wandb.ai/banfizsombor1999/graph-active-learning/runs/5nf3f8eo</a><br/> View project at: <a href='https://wandb.ai/banfizsombor1999/graph-active-learning' target="_blank">https://wandb.ai/banfizsombor1999/graph-active-learning</a><br/>Synced 5 W&B file(s), 0 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20241205_151434-5nf3f8eo/logs</code>

# %%
wandb.finish()

# %%
train_mask = dataset.train_mask.detach().cpu().numpy()

# %%
np.tile(train_mask,11).shape

# %%
ol = []
for _ in range(11):
    ol.append(wrapped_model(dataset))
ol = torch.cat(ol)

# %%
ol.shape
